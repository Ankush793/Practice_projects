# %% [markdown]
# # World Happiness Report

# %% [markdown]
# The World Happiness Report is a landmark survey of the state of global happiness. The first report was published in 2012,
# the second in 2013, the third in 2015, and the fourth in the 2016 Update. The World Happiness 2017, which ranks 155 countries
# by their happiness levels, was released at the United Nations at an event celebrating International Day of Happiness on March
# 20th. The report continues to gain global recognition as governments, organizations and civil society increasingly use
# happiness indicators to inform their policy-making decisions. Leading experts across fields – economics, psychology, survey
# analysis, national statistics, health, public policy and more – describe how measurements of well-being can be used effectively
# to assess the progress of nations. The reports review the state of happiness in the world today and show how the new science of
# happiness explains personal and national variations in happiness.

# %% [markdown]
# # What is Dystopia?

# %% [markdown]
# Dystopia is an imaginary country that has the world’s least-happy people. The purpose in establishing Dystopia is to have a
# benchmark against which all countries can be favorably compared (no country performs more poorly than Dystopia) in terms of
# each of the six key variables, thus allowing each sub-bar to be of positive width. The lowest scores observed for the six key
# variables, therefore, characterize Dystopia. Since life would be very unpleasant in a country with the world’s lowest incomes,
# lowest life expectancy, lowest generosity, most corruption, least freedom and least social support, it is referred to
# as “Dystopia,” in contrast to Utopia.

# %% [markdown]
# # What are the residuals?

# %% [markdown]
# The residuals, or unexplained components, differ for each country, reflecting the extent to which the six variables either
# over- or under-explain average life evaluations. These residuals have an average value of approximately zero over the whole
# set of countries.

# %% [markdown]
# # Happiness scores are based on:

# %% [markdown]
# Data from the Gallup World Poll is used to calculate happiness scores and rankings. These scores are based on answers to the
# main questions asked in the survey. In the Cantril ladder, respondents are asked to imagine themselves on a ladder with the
# best possible life being 10 and the worst possible life being 0. Then they rate the current state of their lives based on that
# ladder.The score is based on national representative samples for the years 2013-2016 and uses Gallup weights to make them
# representative. The columns following the happiness score indicate the relationship between six factors, including economic
# production, social support, life expectancy, freedom, absence of corruption, and generosity - contribute to raising life
# evaluations in each country compared to Dystopia, a hypothetical country with values equal to the world's lowest national
# averages for each factor.The factors do not affect the total score reported for each country, but they explain why some ranked
# higher than others.

# %%
#Lets start importing libraries

# %%
import pandas as pd

# %%
df=pd.read_csv("World_happiness.csv")
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# # Columns Description:

# %% [markdown]
# 1.Happiness Rank:
#     Rank of country in relation to Happiness
#
# 2.Happiness Score:
#     Happiness score is the score calulated on the base of all the factors
#
# 3.Standard Error:
#     It is approximate standard deviation of a statistical sample population
#
# 4.Economy (GDP per Capita):
#     GDP per capita is a country’s economic output divided by its population.It's a good representation of a country's standard
#     of living.
#
# 5.Family:
#     Group of people living together such as parents and child as well as all the relatives who lives together as group.
#
# 6.Health (Life Expectancy):
#     The average period that a person may expect to live.
#
# 7.Freedom:
#     The power or right to act, speak, or think as one wants.
#
# 8.Trust (Government Corruption):
#     firm belief in the reliability, truth, ability, or strength of someone or something.
#     Government Corruption is defined as the abuse of entrusted power or public resources for private gain.
#
# 9.Generosity:
#     the quality of being kind and generous.
#
# 10.Dystopia Residual:
#     The Dystopia Residual metric actually is the Dystopia Happiness Score(1.85) + the Residual value or the unexplained value
#     for each country.

# %%
#we will check the null values first

df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
# there are no null values in the data

# %%
#We will drop the Region column as it will not affect our data and we will make country column as index

# %%
df=df.drop(columns=['Region','Country'])

# %%
df
# Out:
#      Happiness Rank  Happiness Score  Standard Error  \
# 0                 1            7.587         0.03411
# 1                 2            7.561         0.04884
# 2                 3            7.527         0.03328
# 3                 4            7.522         0.03880
# 4                 5            7.427         0.03553
# ..              ...              ...             ...
# 153             154            3.465         0.03464
# 154             155            3.340         0.03656
# 155             156            3.006         0.05015
# 156             157            2.905         0.08658
# 157             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %%
df.shape
# Out:
# (158, 10)

# %% [markdown]
# # EDA:

# %%
df.head(5)
# Out:
#    Happiness Rank  Happiness Score  Standard Error  Economy (GDP per Capita)  \
# 0               1            7.587         0.03411                   1.39651
# 1               2            7.561         0.04884                   1.30232
# 2               3            7.527         0.03328                   1.32548
# 3               4            7.522         0.03880                   1.45900
# 4               5            7.427         0.03553                   1.32629
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                        0.41978
# 1  1.40223                   0.94784  0.62877                        0.14145
# 2  1.36058                   0.87464  0.64938                        0.48357
# 3  1.33095                   0.88521  0.66973                        0.36503
# 4  1.32261                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# ...

# %%
df.tail(5)
# Out:
#      Happiness Rank  Happiness Score  Standard Error  \
# 153             154            3.465         0.03464
# 154             155            3.340         0.03656
# 155             156            3.006         0.05015
# 156             157            2.905         0.08658
# 157             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 153                   0.22208  0.77370                   0.42864  0.59201
# 154                   0.28665  0.35386                   0.31910  0.48450
# 155                   0.66320  0.47489                   0.72193  0.15684
# 156                   0.01530  0.41587                   0.22396  0.11850
# 157                   0.20868  0.13995                   0.28443  0.36453
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 153                        0.55191     0.22628            0.67042
# 154                        0.08010     0.18260            1.63328
# ...

# %%
df.sample(5)
# Out:
#      Happiness Rank  Happiness Score  Standard Error  \
# 139             140            3.956         0.04797
# 73               74            5.399         0.02596
# 56               57            5.828         0.05371
# 65               66            5.695         0.05635
# 108             109            4.694         0.03077
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 139                   0.23906  0.79273                   0.36315  0.22917
# 73                    0.82827  1.08708                   0.63793  0.46611
# 56                    0.59325  1.14184                   0.74314  0.55475
# 65                    1.20806  1.07008                   0.92356  0.49027
# 108                   0.39753  0.43106                   0.60164  0.40820
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 139                        0.19900     0.17441            1.95812
# 73                         0.00000     0.51535            1.86399
# ...

# %%
df.dtypes
# Out:
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# # Correlation and Plots

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Happiness Rank                 158 non-null    int64
#  1   Happiness Score                158 non-null    float64
#  2   Standard Error                 158 non-null    float64
#  3   Economy (GDP per Capita)       158 non-null    float64
#  4   Family                         158 non-null    float64
#  5   Health (Life Expectancy)       158 non-null    float64
#  6   Freedom                        158 non-null    float64
#  7   Trust (Government Corruption)  158 non-null    float64
#  8   Generosity                     158 non-null    float64
#  9   Dystopia Residual              158 non-null    float64
# dtypes: float64(9), int64(1)
# memory usage: 12.5 KB

# %% [markdown]
# we have int and float datatypes available in dataset now, we had country and region also as object but we dropped Region Column and
# set country as an index column

# %%
df_cor=df.corr()
df_cor
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
type(df_cor)
# Out:
# pandas.core.frame.DataFrame

# %%
df.corr()['Happiness Score']
# Out:
# Happiness Rank                  -0.992105
# Happiness Score                  1.000000
# Standard Error                  -0.177254
# Economy (GDP per Capita)         0.780966
# Family                           0.740605
# Health (Life Expectancy)         0.724200
# Freedom                          0.568211
# Trust (Government Corruption)    0.395199
# Generosity                       0.180319
# Dystopia Residual                0.530474
# Name: Happiness Score, dtype: float64

# %%
df.corr()['Happiness Score'].sort_values()                #Economy is 1st, Family is 2nd, Health is 3rd
# Out:
# Happiness Rank                  -0.992105
# Standard Error                  -0.177254
# Generosity                       0.180319
# Trust (Government Corruption)    0.395199
# Dystopia Residual                0.530474
# Freedom                          0.568211
# Health (Life Expectancy)         0.724200
# Family                           0.740605
# Economy (GDP per Capita)         0.780966
# Happiness Score                  1.000000
# Name: Happiness Score, dtype: float64

# %% [markdown]
# # Correlation using heatmap:

# %%
plt.figure(figsize=(10,6))                               # Graphical presentation of Correlation
sns.heatmap(df_cor,annot=True,linewidths=2,linecolor="Darkgreen",cmap="YlOrRd_r",fmt='.2f')

# %% [markdown]
# # Observations from the correlation:

# %% [markdown]
# 1. Happiness Score is negatively correlated (inversely proportional) to Happiness Rank - higher the score, lower the rank
# 2. Happiness score is highly correlated with Economy (78%), Family (74%), Health (72%), and Freedom (57%)
# 3. Economy and Health are strongly correlated (82%) - we would drop one of these two later in the analysis to avoid multicollinearity
# 4. Happiness Rank is negatively correlated with most of the variables as expected - higher the value of other variables, lower the rank
#
# Next step:
# We will drop Happiness Rank column to avoid multicollinearity as it is inversely proportional to our target variable - Happiness Score

# %%
df = df.drop(columns=['Happiness Rank'])

# %%
df.shape
# Out:
# (158, 9)

# %%
df.head()
# Out:
#    Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0            7.587         0.03411                   1.39651  1.34951
# 1            7.561         0.04884                   1.30232  1.40223
# 2            7.527         0.03328                   1.32548  1.36058
# 3            7.522         0.03880                   1.45900  1.33095
# 4            7.427         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# ...

# %% [markdown]
# # Describing Dataset:

# %%
df.describe()
# Out:
#        Happiness Score  Standard Error  Economy (GDP per Capita)      Family  \
# count       158.000000      158.000000                158.000000  158.000000
# mean          5.375734        0.047885                  0.846137    0.991046
# std           1.145010        0.017146                  0.403121    0.272369
# min           2.839000        0.018480                  0.000000    0.000000
# 25%           4.526000        0.037268                  0.545808    0.856823
# 50%           5.232500        0.043940                  0.910245    1.029510
# 75%           6.243750        0.052300                  1.158448    1.214405
# max           7.587000        0.136930                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                158.000000  158.000000                     158.000000
# mean                   0.630259    0.428615                       0.143422
# ...

# %%
plt.figure(figsize=(13,10))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt='f')
plt.xticks(fontsize=20)
plt.yticks(fontsize=14)
plt.title('Variables Summery')
plt.show()

# %% [markdown]
# # Outcome of Describe Dataset:

# %% [markdown]
# from the above plotting we are determining mean,std daviation,minimum and maximum value of each column.
# it helps us further in data cleaning
#
# total number of rows in datasets:
#
#     1. 158 rows
#
#     2. 10 columns
#
# Happiness Rank:
#
#     1.Mean=79.49
#
#     2.std=45.75
#
#     3.max_value=158.00
#
#     4.min_value=1.00
#
# Standard Eror:
#
#     1.Mean=0.05
#
#     2.std=0.02
#
#     3.max_value=0.14
#
#     4.min_value=0.02
#
# Economy (GDP per Capita):
#
#     1.Mean=0.85
#
#     2.std=0.40
#
#     3.max_value=1.69
#
#     4.min_value=0.00
#
# Family:
#
#     1.Mean=0.99
#
#     2.std=0.27
#
#     3.max_value=1.40
#
#     4.min_value=0.00
#
# Health (Life Expectancy):
#
#     1.Mean=0.63
#
#     2.std=0.25
#
#     3.max_value=1.03
#
#     4.min_value=0.00
#
# Freedom:
#
#     1.Mean=0.43
#
#     2.std=0.15
#
#     3.max_value=0.67
#
#     4.min_value=0.00
#
# Trust (Government Corruption):
#
#     1.Mean=0.14
#
#     2.std=0.12
#
#     3.max_value=0.55
#
#     4.min_value=0.00
#
# Generosity:
#
#     1.Mean=0.24
#
#     2.std=0.13
#
#     3.max_value=0.80
#
#     4.min_value=0.00
#
# Dystopia Residual:
#
#     1.Mean=2.10
#
#     2.std=0.55
#
#     3.max_value=3.60
#
#     4.min_value=0.33
#
# Happiness Score:
#
#     1.Mean=5.38
#
#     2.std=1.15
#
#     3.max_value=7.59
#
#     4.min_value=2.84
#
# Happiness Score is the target value.

# %%
sns.pairplot(df)

# %% [markdown]
# # Outliers Checking:

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df.plot(kind='box',subplots=True,layout=(4,4),figsize=(14,18),color='red')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.show()

# %% [raw]
# 1. From above plots, we can see that columns:- 'Happiness Rank','Economy (GDP per Capita)','Health (Life Expectancy)','Freedom' have no outliers.
# 2. Columns:-'Family', 'Generosity','Dystopia Residual' has less outliers.
# 3. Columns:- 'Trust (Government Corruption)' has more outliers.
# 4. Target column:- 'Happiness Score' has no outlires.

# %% [markdown]
# # Checking distribution and Skewness:

# %%
df.skew()
# Out:
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# Outcome of the skewness: Skewness threshold is +/-0.5. Columns which are skewed are:
#
# - Standard Error
# - Family
# - Health (Life Expectancy)
# - Trust (Government Corruption)
# - Generosity

# %% [markdown]
# # Normal Distribution Curve:

# %%
sns.distplot(df['Happiness Score'])

# %% [markdown]
# the data is normalised. the building blocks are normally distributed

# %%
sns.distplot(df['Standard Error'])

# %% [markdown]
# the data is not normalised. the building blocks are out of the normalised curve

# %%
sns.distplot(df['Family'])

# %% [markdown]
# The data is not normalised. the building blocks are out of the normalised curve

# %%
sns.distplot(df['Freedom'])

# %% [markdown]
# The data is not normalised. the building blocks are out of the normalised curve

# %%
sns.distplot(df['Generosity'])

# %% [markdown]
# The data is not normalised. the building blocks are out of the normalised curve

# %%
sns.distplot(df['Dystopia Residual'])

# %%
sns.distplot(df['Trust (Government Corruption)'])

# %% [markdown]
# The data is not normalised. the building blocks are out of the normalised curve

# %%
sns.distplot(df['Health (Life Expectancy)'])

# %% [markdown]
# The data is not normalised. the building blocks are out of the normalised curve

# %%
sns.distplot(df['Economy (GDP per Capita)'])

# %% [markdown]
# The data is not normalised. the building blocks are out of the normalised curve

# %% [markdown]
# # Scatter Plot:

# %%
sns.scatterplot(x='Economy (GDP per Capita)',y='Happiness Score',data=df)

# %% [markdown]
# We can see that as Economy (GDP per Capita) is more Happiness Score of country is also more

# %%
sns.scatterplot(x='Family',y='Happiness Score',data=df)

# %% [markdown]
# We can see that Family and Happiness Score is directly proportional to each other

# %%
sns.scatterplot(x='Health (Life Expectancy)',y='Happiness Score',data=df)

# %% [markdown]
# Health(life Expectancy) and Happiness score is also directly proportional to each other

# %%
sns.scatterplot(x='Freedom',y='Happiness Score',data=df)

# %% [markdown]
# As Freedom is more Happiness Score is also high

# %%
sns.scatterplot(x='Trust (Government Corruption)',y='Happiness Score',data=df)

# %% [markdown]
# as Trust(Government Corruption) increases, Happiness Score is decreases

# %%
sns.scatterplot(x='Generosity',y='Happiness Score',data=df)

# %% [markdown]
# Generosity have not much effect initially but when it increases Happiness Score is decreases after

# %% [markdown]
# # Removing Outliers:

# %% [markdown]
# # Z score Technique:

# %%
from scipy.stats import zscore
import numpy as np

# %%
zscore(df)
# Out:
# array([[ 1.93736005, -0.80592569,  1.36962124, ...,  2.30965159,
#          0.47103971,  0.75825809],
#        [ 1.91458063,  0.05588945,  1.13522625, ..., -0.01647953,
#          1.57585637,  1.09285682],
#        [ 1.88479215, -0.8544869 ,  1.19286069, ...,  2.8427738 ,
#          0.8242928 ,  0.71233526],
#        ...,
#        [-2.0761992 ,  0.13253425, -0.45524543, ...,  0.38141902,
#          1.85689094, -3.20843049],
#        [-2.1646885 ,  2.26396166, -2.06756644, ..., -0.35771452,
#         -0.31694987, -0.48198451],
#        [-2.22251319,  1.13418227, -1.58633379, ..., -0.30180313,
#         -0.5581534 , -0.96361241]])

# %%
z=np.abs(zscore(df))
z.shape
# Out:
# (158, 9)

# %%
z
# Out:
# array([[1.93736005, 0.80592569, 1.36962124, ..., 2.30965159, 0.47103971,
#         0.75825809],
#        [1.91458063, 0.05588945, 1.13522625, ..., 0.01647953, 1.57585637,
#         1.09285682],
#        [1.88479215, 0.8544869 , 1.19286069, ..., 2.8427738 , 0.8242928 ,
#         0.71233526],
#        ...,
#        [2.0761992 , 0.13253425, 0.45524543, ..., 0.38141902, 1.85689094,
#         3.20843049],
#        [2.1646885 , 2.26396166, 2.06756644, ..., 0.35771452, 0.31694987,
#         0.48198451],
#        [2.22251319, 1.13418227, 1.58633379, ..., 0.30180313, 0.5581534 ,
#         0.96361241]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157]), array([6, 1, 1, 1, 7, 3, 6, 8, 3]))

# %%
# We will remove the outliers in a way that keeps only those data points that fall under the 3 standard deviations.

# %%
df_new = df[(z<3).all(axis=1)]

# %%
print("Old DataFrame",df.shape)
print("New DataFrame", df_new.shape)
print("total dropped rows", df.shape[0]-df_new.shape[0])
# Out:
# Old DataFrame (158, 9)
# New DataFrame (149, 9)
# total dropped rows 9

# %% [markdown]
# # Percentage Data Loss:

# %%
loss_percent=(158-149)/158*100
print('loss_percent:-', loss_percent,'%')
# Out:
# loss_percent:- 5.69620253164557 %

# %% [markdown]
# # Spliiting the data into x and y:

# %%
df_new.columns
# Out:
# Index(['Happiness Score', 'Standard Error', 'Economy (GDP per Capita)',
#        'Family', 'Health (Life Expectancy)', 'Freedom',
#        'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
# Splitting the Data into X Dataset

x=df_new[['Economy (GDP per Capita)', 'Family',
       'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
       'Generosity','Dystopia Residual']]

# %%
#splitting the data in y Dataset

y=df_new['Happiness Score']

# %%
x.shape
# Out:
# (149, 7)

# %%
y.shape
# Out:
# (149,)

# %%
x           #independent variables
# Out:
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# ..                        ...      ...                       ...      ...
# 150                   0.46534  0.77115                   0.15185  0.46866
# 151                   0.25812  0.85188                   0.27125  0.39493
# 152                   0.31982  0.30285                   0.30335  0.23414
# 154                   0.28665  0.35386                   0.31910  0.48450
# 156                   0.01530  0.41587                   0.22396  0.11850
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# ...

# %%
y            #target Variable
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 150    3.655
# 151    3.587
# 152    3.575
# 154    3.340
# 156    2.905
# Name: Happiness Score, Length: 149, dtype: float64

# %% [markdown]
# It clearly shows on the above 2 cells that the feature and label data have been separated successfully using the new data
# set of 149 rows each.

# %%
x.dtypes
# Out:
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# # Relationship Between Target and Feature vectors:

# %%
plt.figure(figsize=(20,30),facecolor='white')
plotnumber=1

for column in x:
    if plotnumber<=16:
        ax=plt.subplot(4,4,plotnumber)
        plt.scatter(x[column],y)
        plt.xlabel(column,fontsize=20)
        plt.ylabel('Happiness Score',fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# - Economy, Family, Health, Freedom, Dystopia Residual, have impact on happiness score, as these increases, Happiness rank also increases.
#
# - Trust and generosity has less impact, as trust goes down, happiness score goes down and same with the generosity.

# %% [markdown]
# # Transforming data to remove skewness:

# %%
# from sklearn.preprocessing import power_transform
# x=power_transform(x,method='yeo-johnson')
# x

# %% [markdown]
# # Standard scaler:

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import normalize
# sc=StandardScaler()
x_scaled=normalize(x, norm='l2', axis=1)
x_scaled
# Out:
# array([[ 0.39155557,  0.43521858,  0.38556918, ...,  0.47686642,
#          0.17304495,  0.1981464 ],
#        [ 0.32365149,  0.54457264,  0.40963508, ...,  0.08935859,
#          0.42354329,  0.3011818 ],
#        [ 0.34356985,  0.46947748,  0.28575476, ...,  0.52986187,
#          0.26507364,  0.19163745],
#        ...,
#        [-0.41010384, -0.62704088, -0.40625047, ..., -0.05792916,
#          0.3407253 , -0.09826374],
#        [-0.47590845, -0.66766196, -0.4349504 , ..., -0.14429539,
#         -0.1036408 , -0.3095687 ],
#        [-0.5261481 , -0.51737226, -0.42082749, ..., -0.03996794,
#         -0.04681024, -0.15023699]])

# %% [markdown]
# # Since the outcome is Continuous values we will use Linear Regression on model.

# %%
#importing Machine Learning Libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RandomizedSearchCV
import pickle
from sklearn.metrics import adjusted_rand_score

# %%
print(x_scaled.shape)
# Out:
# (149, 7)

# %%
print(y.shape)
# Out:
# (149,)

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,random_state=45,test_size=0.25)

# %%
x_train.shape
# Out:
# (111, 7)

# %%
x_test.shape
# Out:
# (38, 7)

# %%
y_train.shape
# Out:
# (111,)

# %%
y_test.shape
# Out:
# (38,)

# %% [markdown]
# # Linear Regression

# %%
# Linear Regression:
lr=LinearRegression()

# training
lr.fit(x_train, y_train)

# prediction
y_pred_lr = lr.predict(x_test)

# The coefficients
print("Coefficients: \n", lr.coef_)

# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred_lr))

# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination/R-Square: %.2f" % r2_score(y_test, y_pred_lr))

# Plot outputs
# plt.scatter(x_test[:,1], y_test, color="black")
plt.scatter(y_test, y_pred_lr, color="blue", linewidth=3, marker=".")

plt.xlabel("y_test")
plt.ylabel("y_pred")

plt.show()
# Out:
# Coefficients:
#  [0.84944027 0.76361986 0.86303914 0.39197088 0.28170326 0.32856927
#  1.25784019]
# Mean squared error: 0.07
# Coefficient of determination/R-Square: 0.95

# %%
# Cross Valiodation
from sklearn.model_selection import cross_val_score
k = 5
cv_result = cross_val_score(lr,x_train,y_train,cv=k) # uses R^2 as score 
print('CV Scores: ',cv_result)
print('CV scores average: ',np.sum(cv_result)/k)
# Out:
# CV Scores:  [0.94310848 0.94748083 0.88333771 0.90355251 0.95389916]
# CV scores average:  0.9262757384564931

# %% [markdown]
# # Decision Tree Regression

# %%
# Decision tree regression
dt=DecisionTreeRegressor()

# training
dt.fit(x_train, y_train)

# prediction
y_pred_dt = dt.predict(x_test)

# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred_dt))

# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination/R-Square: %.2f" % r2_score(y_test, y_pred_dt))

# Plot outputs
# plt.scatter(x_test[:,1], y_test, color="black")
plt.scatter(y_test, y_pred_dt, color="blue", linewidth=3, marker=".")

plt.xlabel("y_test")
plt.ylabel("y_pred")

plt.show()
# Out:
# Mean squared error: 0.34
# Coefficient of determination/R-Square: 0.75

# %%
# grid search cross validation with 1 hyperparameter
from sklearn.model_selection import GridSearchCV
grid = {'min_samples_leaf': np.arange(1,10),"criterion":["mse","friedman_mse","mae"]}

dt_cv = GridSearchCV(dt, grid, cv=5) # GridSearchCV
dt_cv.fit(x_train,y_train) # Fit

# Print hyperparameter
print("Tuned hyperparameter k: {}".format(dt_cv.best_params_)) 
print("Best score: {}".format(dt_cv.best_score_))
# Out:
# Tuned hyperparameter k: {'criterion': 'mse', 'min_samples_leaf': 1}
# Best score: 0.7289858083557558

# %% [markdown]
# # Random Forest Regression

# %%
# Random forest regression
rf=RandomForestRegressor()

# training
rf.fit(x_train, y_train)

# prediction
y_pred_rf = rf.predict(x_test)

# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred_rf))

# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination/R-Square: %.2f" % r2_score(y_test, y_pred_rf))

# Plot outputs
# plt.scatter(x_test[:,1], y_test, color="black")
plt.scatter(y_test, y_pred_rf, color="blue", linewidth=3, marker=".")

plt.xlabel("y_test")
plt.ylabel("y_pred")

plt.show()
# Out:
# Mean squared error: 0.17
# Coefficient of determination/R-Square: 0.88

# %%
# grid search cross validation with 1 hyperparameter
grid = {'min_samples_leaf': np.arange(1,10),"criterion":["mse","friedman_mse","mae"]}

rf_cv = GridSearchCV(rf, grid, cv=5) # GridSearchCV
rf_cv.fit(x_train,y_train) # Fit

# Print hyperparameter
print("Tuned hyperparameter k: {}".format(rf_cv.best_params_)) 
print("Best score: {}".format(rf_cv.best_score_))
# Out:
# Tuned hyperparameter k: {'criterion': 'friedman_mse', 'min_samples_leaf': 1}
# Best score: 0.8703150937391729

# %% [markdown]
# # **Support Vector Regression**

# %%
# SV regression
svr = SVR()

# training
svr.fit(x_train, y_train)

# prediction
y_pred_svr = svr.predict(x_test)

# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred_svr))

# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination/R-Square: %.2f" % r2_score(y_test, y_pred_svr))

# Plot outputs
# plt.scatter(x_test[:,1], y_test, color="black")
plt.scatter(y_test, y_pred_svr, color="blue", linewidth=3, marker=".")

plt.xlabel("y_test")
plt.ylabel("y_pred")

plt.show()
# Out:
# Mean squared error: 0.07
# Coefficient of determination/R-Square: 0.95

# %%
# grid search cross validation with 1 hyperparameter

grid = {'kernel' : ('linear', 'poly', 'rbf', 'sigmoid'),'C' : [1,5,10],'degree' : [3,8],'coef0' : [0.01,10,0.5],'gamma' : ('auto','scale')}

svr_cv = GridSearchCV(svr, grid, cv=3) # GridSearchCV
svr_cv.fit(x_train,y_train) # Fit

# Print hyperparameter
print("Tuned hyperparameter k: {}".format(svr_cv.best_params_)) 
print("Best score: {}".format(svr_cv.best_score_))
# Out:
# Tuned hyperparameter k: {'C': 1, 'coef0': 0.01, 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf'}
# Best score: 0.9506799520821051

# %% [markdown]
# # KNN Regression

# %%
# KNN regression
knn = KNeighborsRegressor()

# training
knn.fit(x_train, y_train)

# prediction
y_pred_knn = knn.predict(x_test)

# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred_knn))

# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination/R-Square: %.2f" % r2_score(y_test, y_pred_knn))

# Plot outputs
# plt.scatter(x_test[:,1], y_test, color="black")
plt.scatter(y_test, y_pred_knn, color="blue", linewidth=3, marker=".")

plt.xlabel("y_test")
plt.ylabel("y_pred")

plt.show()
# Out:
# Mean squared error: 0.16
# Coefficient of determination/R-Square: 0.89

# %%
# Cross Valiodation
k = 5
knn_cv = cross_val_score(knn,x_train,y_train,cv=k) # uses R^2 as score 
print('CV Scores: ', knn_cv)
print('CV scores average: ',np.sum(knn_cv)/k)
# Out:
# CV Scores:  [0.7859439  0.91978914 0.84526602 0.88339063 0.86993596]
# CV scores average:  0.8608651318295673

# %% [markdown]
# # Evaluation metrics:

# %%
sq_errorlr=mean_squared_error(y_test,y_pred_lr)
sq_errordtr=mean_squared_error(y_test,y_pred_dt)
sq_errorrfr=mean_squared_error(y_test,y_pred_rf)
sq_errorsvr=mean_squared_error(y_test,y_pred_svr)
sq_errorknr=mean_squared_error(y_test,y_pred_knn)

rmse_lr=sqrt(sq_errorlr)                                #rmse=root mean squared error
rmse_svr=sqrt(sq_errorsvr)
rmse_dtr=sqrt(sq_errordtr)
rmse_rfr=sqrt(sq_errorrfr)
rmse_knr=sqrt(sq_errorknr)

print("RMSE of Linear Regression is: ", rmse_lr)
print("RMSE of Decision Tree Regressor is: ", rmse_dtr)
print("RMSE of Random Forest Regressor is: ", rmse_rfr)
print("RMSE of Support Vector Regression is: ", rmse_svr)
print("RMSE of K Neighbors Regressor is: ", rmse_knr)
# Out:
# RMSE of Linear Regression is:  0.2679719104464721
# RMSE of Decision Tree Regressor is:  0.5869034709477584
# RMSE of Random Forest Regressor is:  0.4166618367074445
# RMSE of Support Vector Regression is:  0.26291249173512915
# RMSE of K Neighbors Regressor is:  0.3993085668739745

# %% [markdown]
# Support Vector Regression has the lowest RMSE, followed by linear regression, KNN regressor, random forest regressor, and decision tree regressor

# %%
#R2 Score for the model:

print("R2 Score for Linear Regression is:",r2_score(y_test,y_pred_lr))
print("R2 Score for Decision Tree Regressor  is:",r2_score(y_test,y_pred_dt))
print("R2 Score for Random Forest Regressor  is:",r2_score(y_test,y_pred_rf))
print("R2 Score for Support Vector Regression is:",r2_score(y_test,y_pred_svr))
print("R2 Score for K Neighbors Regressor  is:",r2_score(y_test,y_pred_knn))
# Out:
# R2 Score for Linear Regression is: 0.9485513393437244
# R2 Score for Decision Tree Regressor  is: 0.7532092462810825
# R2 Score for Random Forest Regressor  is: 0.8756164417938196
# R2 Score for Support Vector Regression is: 0.9504757427487028
# R2 Score for K Neighbors Regressor  is: 0.8857614231885099

# %% [markdown]
# We use R2 score to evaluate the model and check the accuracy by which we would be able to choose our best regression model.
#
# Support Vector Regression has the highest R2 score, followed by linear regression, KNN regressor, random forest regressor, and decision tree regressor

# %% [markdown]
# # **Support Vector Regressor (SVR) is the best performing model**
# ### SVR has the highest R2 score of 95% and the lowest RMSE of 26% as compared to all the other models

# %% [markdown]
# # Saving the model:

# %%
file="Final_World_Happiness.pkl"
pickle.dump(svr,open(file,'wb'))

# %%
import numpy as np
a=np.array(y_test)
predicted=np.array(svr.predict(x_test))
df_com=pd.DataFrame({"original":a,"predicted":predicted}, index=range(len(a)))
df_com
# Out:
#     original  predicted
# 0      7.587   7.268724
# 1      5.987   5.901774
# 2      4.218   4.779564
# 3      7.522   7.281122
# 4      6.329   6.271569
# 5      5.984   5.861775
# 6      6.269   6.245863
# 7      4.550   4.454498
# 8      4.350   4.580530
# 9      3.819   4.488388
# 10     6.574   6.768910
# 11     3.956   4.039055
# 12     4.565   4.373851
# 13     4.786   4.295077
# 14     3.995   3.864812
# 15     6.302   6.335652
# 16     3.655   3.745350
# 17     3.681   3.765799
# 18     6.123   6.189285
# 19     5.057   4.962521
# 20     5.102   5.219694
# 21     5.098   4.931088
# 22     4.518   4.407233
# 23     5.855   5.944643
# 24     7.427   7.321125
# 25     4.610   4.397404
# 26     4.959   4.850578
# 27     5.605   5.744930
# 28     7.278   6.846256
# 29     4.971   5.038075
# 30     5.212   5.130035
# 31     4.739   4.844306
# 32     3.896   4.329142
# 33     4.800   4.956357
# 34     6.750   7.009782
# 35     3.904   3.625807
# 36     7.187   6.531611
# ...

# %% [markdown]
# # Loading the model:

# %%
load_model=pickle.load(open(file,'rb'))
result=load_model.score(x_test,y_test)*100
print(result)
# Out:
# 95.04757427487029

# %% [markdown]
# Finally I have loaded the saved model and passed the unseen data set to predict the model score.

# %%
plt.xlabel('original score')
plt.ylabel('predicted score')
plt.scatter(y_test,y_pred_svr,color='blue')
plt.show
# Out:
# <function matplotlib.pyplot.show>
